# %% [markdown]
# # Machine Learning is everywhere... and usually you don't even notice it
#
# <img src="img/search.png", width="40%">
#
# <img src="img/resulset.png", width="40%">
#
# <img src="img/translate.png", width="40%">
#
# <img src="img/gmail.jpg", width="40%">
#
# <img src="img/netflix.jpg", width="40%">
#
# <img src="img/fb.jpg", width="40%">
#
# <img src="img/cad.jpg", width="40%">
#
# <img src="img/selfdrivingcar.jpg", width="40%">
#
#
# # Advanced Machine Learning Applications
#
#  [**Segmentation**](http://mi.eng.cam.ac.uk/projects/segnet/).
#
# --------------------
#
# RNNs: [**Language and Vision**](http://visualqa.csail.mit.edu/)
#
# --------------------
#
# **Playing Mario**
# [**like a boss**](https://www.youtube.com/watch?v=qv6UVOQ0F44).
# [**Reinforcement Learning**](https://www.youtube.com/watch?v=L4KBBAwF_bE).
#
# <img src="img/mario.png", width="40%">
#
#  <img src="img/alphago.png", height=1000>
#
# --------------------
#
# [**Generative Models**](https://youtu.be/9c4z6YsBGQ0).
#
# --------------------
#
# [**Image Colorization!!**](http://richzhang.github.io/colorization/).
#
# --------------------
#
# **Visual Style Transfer for images:**
# <img src="img/a_nerual_algorithm_of_artistic_style.jpg", height=1000>
#
# --------------------
#
# With these ideas, you can do
# [**crazy things!**](http://dmitryulyanov.github.io/feed-forward-neural-doodle/).
#
# --------------------
#
# [**Visual Style Transfer for videos!!**](https://www.youtube.com/watch?v=Khuj4ASldmU).
#
# **NeuralTalk**
#
# [**real-time scene understanding**](https://www.youtube.com/watch?v=8BFzu9m52sc).
#
# **Face2Face**
# [**It wasn't me**](https://www.youtube.com/watch?v=ohmajJTcpNk).
#
# <img src="img/face2face.jpg", width="40%">
#
# **Snapchat acquires Looksery for 150M**
#
# <img src="img/snapchat.jpg", width="20%">
#
# **Some industrial applications**
#
# <img src="img/cinex.png", width="24%">
# <img src="img/insighter.png", width="24%">
# <img src="img/mmm.png", width="24%">
# <img src="img/oe.jpg", width="24%">
